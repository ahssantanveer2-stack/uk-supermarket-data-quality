# %% [markdown]
# # UK Supermarket Data Export Verification
#
# ## Project Overview
#
# This notebook verifies that the cleaned datasets were successfully exported during the data cleaning stage.
#
# The cleaned datasets are loaded and checked before being used for SQL analysis and Power BI dashboard development.

# %%
import pandas as pd

# %%
aldi = pd.read_csv("../data/cleaned/aldi_clean.csv")

asda = pd.read_csv("../data/cleaned/asda_clean.csv")

morrisons = pd.read_csv("../data/cleaned/morrisons_clean.csv")

sains = pd.read_csv("../data/cleaned/sains_clean.csv")

tesco = pd.read_csv("../data/cleaned/tesco_clean.csv")
# Out:
# C:\Users\Atq12\AppData\Local\Temp\ipykernel_11656\3468421477.py:3: DtypeWarning: Columns (0: own_brand) have mixed types. Specify dtype option on import or set low_memory=False.
#   asda = pd.read_csv("../data/cleaned/asda_clean.csv")

# %%
print("Aldi:", aldi.shape)

print("ASDA:", asda.shape)

print("Morrisons:", morrisons.shape)

print("Sainsbury's:", sains.shape)

print("Tesco:", tesco.shape)
# Out:
# Aldi: (464863, 8)
# ASDA: (2456407, 8)
# Morrisons: (1794065, 8)
# Sainsbury's: (2600289, 8)
# Tesco: (2189783, 8)

# %%
for name, df in {
    "Aldi": aldi,
    "ASDA": asda,
    "Morrisons": morrisons,
    "Sainsbury's": sains,
    "Tesco": tesco
}.items():

    print("=" * 40)
    print(name)
    print(df.columns.tolist())
# Out:
# ...
# Aldi
# ['supermarket', 'prices_(£)', 'prices_unit_(£)', 'unit', 'names', 'date', 'category', 'own_brand']
# ...
# ASDA
# ['supermarket', 'prices_(£)', 'prices_unit_(£)', 'unit', 'names', 'date', 'category', 'own_brand']
# ...
# Morrisons
# ['supermarket', 'prices_(£)', 'prices_unit_(£)', 'unit', 'names', 'date', 'category', 'own_brand']
# ...
# Sainsbury's
# ['supermarket', 'prices_(£)', 'prices_unit_(£)', 'unit', 'names', 'date', 'category', 'own_brand']
# ...
# Tesco
# ['supermarket', 'prices_(£)', 'prices_unit_(£)', 'unit', 'names', 'date', 'category', 'own_brand']

# %% [markdown]
# # Export Verification Summary
#
# The cleaned datasets were successfully loaded from the `data/cleaned` directory.
#
# Verification confirmed:
#
# - All datasets loaded without errors.
# - Dataset dimensions matched the expected results after cleaning.
# - The exported files retain the expected column structure.
#
# These datasets are now ready for SQL analysis and Power BI dashboard development.
